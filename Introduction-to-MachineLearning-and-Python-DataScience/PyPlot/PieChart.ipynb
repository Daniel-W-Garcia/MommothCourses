# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
pie_chart_data = {'Dan': 25, 'Eric': 40, 'Rick': 30, 'Andrew': 5}
explode_values = [0,0,0,.2]
plt.pie(pie_chart_data.values(), labels=pie_chart_data.keys(), startangle=190, explode=explode_values, shadow=True)
plt.show()
