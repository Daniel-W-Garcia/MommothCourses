# %%
import os
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Histogram
histogram_data = np.random.randint(1, 11, size=100)
plt.hist(histogram_data)
plt.xlabel('Number')
plt.ylabel('Times Occures')
plt.title('random.randint chart')
plt.show()
